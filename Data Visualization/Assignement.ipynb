# %%
import matplotlib.pyplot as plt
import pandas as pd
from fontTools.ttLib.tables.C_P_A_L_ import Color

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    Year  Rohit_Sharma_Runs  Virat_Kohli_Runs
# 0  2011               1200              1400
# 1  2012               1350              1600
# 2  2013               1500              1750
# 3  2014               1650              1900
# 4  2015               1800              2100

# %%
plt.plot(df["Year"], df["Rohit_Sharma_Runs"],color="blue", label="Rohit_Sharma_Runs")
plt.plot(df["Year"], df["Virat_Kohli_Runs"], color="red" ,label="Virat_Kohli_Runs")
plt.xlabel("Year")
plt.ylabel("Runs")
plt.legend()
plt.show()

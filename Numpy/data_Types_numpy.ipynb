# %%
import numpy as np

# %%
arr = np.array([1,4,34,22])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype(float)
# Out:
# array([ 1.,  4., 34., 22.])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr = np.array([1,2,3,4], dtype = "float32")

# %%
arr.dtype
# Out:
# dtype('float32')

# %%
arr.nbytes
# Out:
# 16

# %%
complexArr = np.array([1+2j, 3+4j, 5+6j, 7+8j])

# %%
complexArr.dtype
# Out:
# dtype('complex128')

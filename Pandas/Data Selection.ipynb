# %%
from pickletools import pyset

import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df["Actor"]
# Out:
# 0         Shah Rukh Khan
# 1            Salman Khan
# 2             Aamir Khan
# 3          Ranbir Kapoor
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 9          Kartik Aaryan
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
df[["Actor", "IMDb"]]
# Out:
#                  Actor  IMDb
# 0       Shah Rukh Khan   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df.loc[1]
# Out:
# Actor                       Salman Khan
# Film                    Tiger Zinda Hai
# Year                               2017
# Genre                            Action
# BoxOffice(INR Crore)                565
# IMDb                                6.0
# Name: 1, dtype: object

# %%
df.loc[8, "IMDb"]
# Out:
# np.float64(7.0)

# %%
df.loc[0:3, ["Actor", "Film"]]
# Out:
#             Actor             Film
# 0  Shah Rukh Khan          Pathaan
# 1     Salman Khan  Tiger Zinda Hai
# 2      Aamir Khan           Dangal
# 3   Ranbir Kapoor       Brahmastra

# %%
df.at[0, "Film"]
# Out:
# 'Pathaan'

# %%
df[df["IMDb"] > 6]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# ...

# %%
df[(df["IMDb"] > 6) & (df["Year"] > 2018)]
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 8     Akshay Kumar                Good Newwz  2019  Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %%
df.query("Year > 2018 and IMDb > 6")
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 8     Akshay Kumar                Good Newwz  2019  Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %%
physics = pd.read_excel("physics.xlsx")

# %%
physics
# Out:
#                                             Module -1  \
# 0                             Concept of interference
# 1                                                 NaN
# 2        Interference in thin films (reflected light)
# 3   Newton's Rings and Michelson's Interferometer,...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                              Concept of Diffraction
# 8                  Single slit Fraunhofer Diffraction
# 9                    Diffraction Grating and Spectrum
# 10                        Determination of Wavelength
# 11      Application of Grating as wavelength splitter
# 12                                                NaN
# 13                                                NaN
# 14                                           Module-2
# 15                  Einstein's Theory of laser action
# ...

# %%
physics = pd.read_excel("CSE.xlsx")
physics
# Out:
#                                   NIELIT , AURANGABAD      Unnamed: 1  \
# 0   Continuous Assessment (Theory) for Students of...             NaN
# 1                                                 NaN             NaN
# 2                                               Sr.No  Student Reg.No
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# ..                                                ...             ...
# 65                                                NaN             NaN
# 66                                                NaN             NaN
# 67                                                NaN             NaN
# 68                                                NaN             NaN
# 69                                                NaN             NaN
#
#                   Unnamed: 2                     Unnamed: 3        Unnamed: 4  \
# ...

# %%
data = physics.loc[5:, ["NIELIT , AURANGABAD", "Unnamed: 1", "Unnamed: 2", "Unnamed: 4", "Unnamed: 7", "Unnamed: 9"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 data = physics.loc[5:, ["NIELIT , AURANGABAD", "Unnamed: 1", "Unnamed: 2", "Unnamed: 4", "Unnamed: 7", "Unnamed: 9"]]
#
# File E:\JupyterProject\.venv\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File E:\JupyterProject\.venv\Lib\site-packages\pandas\core\indexing.py:1378, in _LocIndexer._getitem_tuple(self, tup)
#    1375 if self._multi_take_opportunity(tup):
#    1376     return self._multi_take(tup)
# -> 1378 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
data
# Out:
#    NIELIT , AURANGABAD    Unnamed: 1                  Unnamed: 2  \
# 5                    1  NDU202500185            Shaik Nizamuddin
# 6                    2  NDU202500186                  Piyush Raj
# 7                    3  NDU202500187  Guvvala Nanivardhan\nReddy
# 8                    4  NDU202500188                 Adesh Dahat
# 9                    5  NDU202500189                 Lucky Patel
# ..                 ...           ...                         ...
# 65                 NaN           NaN                         NaN
# 66                 NaN           NaN    Signature of the Faculty
# 67                 NaN           NaN                         NaN
# 68                 NaN           NaN                         NaN
# 69                 NaN           NaN                         NaN
#
#           Unnamed: 4 Unnamed: 7 Unnamed: 9
# 5               32.5         25       57.5
# 6               32.5         30       62.5
# 7               32.5         15       47.5
# ...

# %%
data.rename(columns={"NIELIT , AURANGABAD": "Roll", "Unnamed: 1 ": "NUD", "Unnamed: 2": "Name","Unnamed: 4": "Mark1", "Unnamed: 7": "Mark2", "Unnamed: 9":  "Total"}, inplace=True)

# %%
data.columns
# Out:
# Index(['Roll', 'Unnamed: 1', 'Name', 'Mark1', 'Mark2', 'Total'], dtype='object')

# %%
data
# Out:
#    Roll    Unnamed: 1                        Name             Mark1 Mark2  \
# 5     1  NDU202500185            Shaik Nizamuddin              32.5    25
# 6     2  NDU202500186                  Piyush Raj              32.5    30
# 7     3  NDU202500187  Guvvala Nanivardhan\nReddy              32.5    15
# 8     4  NDU202500188                 Adesh Dahat              32.5    25
# 9     5  NDU202500189                 Lucky Patel              32.5    30
# ..  ...           ...                         ...               ...   ...
# 65  NaN           NaN                         NaN               NaN   NaN
# 66  NaN           NaN    Signature of the Faculty               NaN   NaN
# 67  NaN           NaN                         NaN  Arnab Chatterjee   NaN
# 68  NaN           NaN                         NaN               NaN   NaN
# 69  NaN           NaN                         NaN               NaN   NaN
#
#    Total
# 5   57.5
# 6   62.5
# 7   47.5
# 8   57.5
# 9   62.5
# ..   ...
# ...

# %%
data.rename({"Unnamed: 1": "NDU"}, inplace=True)

# %%
data
# Out:
#    Roll    Unnamed: 1                        Name             Mark1 Mark2  \
# 5     1  NDU202500185            Shaik Nizamuddin              32.5    25
# 6     2  NDU202500186                  Piyush Raj              32.5    30
# 7     3  NDU202500187  Guvvala Nanivardhan\nReddy              32.5    15
# 8     4  NDU202500188                 Adesh Dahat              32.5    25
# 9     5  NDU202500189                 Lucky Patel              32.5    30
# ..  ...           ...                         ...               ...   ...
# 65  NaN           NaN                         NaN               NaN   NaN
# 66  NaN           NaN    Signature of the Faculty               NaN   NaN
# 67  NaN           NaN                         NaN  Arnab Chatterjee   NaN
# 68  NaN           NaN                         NaN               NaN   NaN
# 69  NaN           NaN                         NaN               NaN   NaN
#
#    Total
# 5   57.5
# 6   62.5
# 7   47.5
# 8   57.5
# 9   62.5
# ..   ...
# ...

# %%
data
# Out:
#    Roll    Unnamed: 1                           Name  Mark1 Mark2  Total
# 5     1  NDU202500185               Shaik Nizamuddin   32.5    25   57.5
# 6     2  NDU202500186                     Piyush Raj   32.5    30   62.5
# 7     3  NDU202500187     Guvvala Nanivardhan\nReddy   32.5    15   47.5
# 8     4  NDU202500188                    Adesh Dahat   32.5    25   57.5
# 9     5  NDU202500189                    Lucky Patel   32.5    30   62.5
# 10    6  NDU202500190           Kurimineni Durga Sai   32.5    25   57.5
# 11    7  NDU202500191              Sujaay Kadorkajan  29.25    20  49.25
# 12    8  NDU202500192                  Sarthak Verma     26    28     54
# 13    9  NDU202500193                Divyanshu Yadav   32.5    25   57.5
# 14   10  NDU202500194         Rohitash Singh Rathore     26    22     48
# 15   11  NDU202500195              Harshal Hingankar     26    24     50
# 16   12  NDU202500196               Macharla Ganguly     26    25     51
# ...

# %%
data.query("Total > 55")
# Out:
#    Roll    Unnamed: 1                        Name Mark1 Mark2 Total
# 5     1  NDU202500185            Shaik Nizamuddin  32.5    25  57.5
# 6     2  NDU202500186                  Piyush Raj  32.5    30  62.5
# 8     4  NDU202500188                 Adesh Dahat  32.5    25  57.5
# 9     5  NDU202500189                 Lucky Patel  32.5    30  62.5
# 10    6  NDU202500190        Kurimineni Durga Sai  32.5    25  57.5
# 13    9  NDU202500193             Divyanshu Yadav  32.5    25  57.5
# 18   14  NDU202500198                Aditya Kumar  32.5  32.5    65
# 19   15  NDU202500199  Jaiswal Vinod Mata\nPrasad  32.5    27  59.5
# 21   17  NDU202500201        Adarsh Pruthvi patil  32.5    27  59.5
# 23   19  NDU202500203          Pushpendra Chauhan  32.5    32  64.5
# 24   20  NDU202500204           Chanda Sudharshan    26    32    58
# 26   22  NDU202500206              Shreyash Tigga  32.5    28  60.5
# 28   24  NDU202500208                       Rahul  32.5    28  60.5
# ...

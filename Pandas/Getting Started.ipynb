# %%
import pandas as pd

# %%
s1 = pd.Series([75,95,76,74,89,99])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
print(s1)
# Out:
# 0    75
# 1    95
# 2    76
# 3    74
# 4    89
# 5    99
# dtype: int64

# %%
s2 = pd.Series([75,95,76,74], index = ["Rohit", "Rohan", "Rahul", "Deepak"], dtype = "int32")

# %%
print(s2)
# Out:
# Rohit     75
# Rohan     95
# Rahul     76
# Deepak    74
# dtype: int32

# %%
data = {
        "name": ["Tan", "Cos", "Sine"],
        "angle": [45, 0, 90],
        "value": [1,1,1]
}

# %%
df = pd.DataFrame(data)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'angle', 'value'], dtype='object')

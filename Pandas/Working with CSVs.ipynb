# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df = df.query("IMDb > 6")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# ...

# %%
df.to_csv("data_updated.csv")

# %%
df = pd.read_excel("data.xlsx")

# %%
df
# Out:
#                    Student Name  Present Day Percentage(Sept)  \
# 0              Shaik Nizamuddin                        100.00
# 1                    Piyush Raj                         42.86
# 2   Guvvala nanni Vardhan Reddy                         92.86
# 3                   Adesh Dahat                         64.29
# 4                   Lucky Patel                         92.86
# ..                          ...                           ...
# 57              Pratiksha Patil                         57.14
# 58        Tejal Prashant Zakade                         28.57
# 59     Suradkar sumedh Rajendra                         28.57
# 60        Bhalerao mansi Sachin                          7.14
# 61            Viresh Amar Singh                          7.14
#
#     Present Day Percentage(Oct)  Present Day Percentage(Nov)  \
# 0                         91.67                        100.0
# 1                        100.00                        100.0
# ...

# %%
df = df.query("`Oveall Percentage` > 80")

# %%
df
# Out:
#                    Student Name  Present Day Percentage(Sept)  \
# 0              Shaik Nizamuddin                        100.00
# 1                    Piyush Raj                         42.86
# 2   Guvvala nanni Vardhan Reddy                         92.86
# 4                   Lucky Patel                         92.86
# 5          Kurtminent durga sai                        100.00
# 6             Sujaay Kadorkajan                        100.00
# 7                 Sarthak Verma                        100.00
# 8               Divyanshu Yadav                        100.00
# 9        Rohitash Singh Rathore                        100.00
# 11            Harshal Hingankar                         64.29
# 12             Macharla Ganguly                         92.86
# 14                 Aditya Kumar                        100.00
# 15    Jaiswal Vinod Mata Prasad                        100.00
# 16             Abhinandan Kumar                        100.00
# ...

# %%
with pd.ExcelWriter("Eligible.xlsx") as writer:
        df.to_excel(writer, sheet_name="Sheet1")
